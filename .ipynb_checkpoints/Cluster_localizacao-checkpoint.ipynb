# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
rain = pd.read_csv('./data/rain_data_aus.csv')

# %%
from opencage.geocoder import OpenCageGeocode

key = '46b48d2d3d8f4acb88f582e3a83cbe77'
geocoder = OpenCageGeocode(key)

city_lat = {}
city_lng = {}

for city in rain['location'].unique():
    query = f'{city}, Australia'
    results = geocoder.geocode(query)
    city_lat[city] =results[0]['geometry']['lat']
    city_lng[city] =results[0]['geometry']['lng']

# %%
cities = pd.DataFrame(data=[city_lat,city_lng]).T

# %%
cities = cities.reset_index()
cities.columns= ['location','lat','lng']

# %%
rain = pd.merge(left=rain,right=cities,on='location')

# %%
rain.columns
# Out:
# Index(['date', 'location', 'mintemp', 'maxtemp', 'rainfall', 'evaporation',
#        'sunshine', 'humidity9am', 'humidity3pm', 'pressure9am', 'pressure3pm',
#        'cloud9am', 'cloud3pm', 'temp9am', 'temp3pm', 'raintoday',
#        'amountOfRain', 'raintomorrow', 'temp', 'humidity', 'precipitation3pm',
#        'precipitation9am', 'modelo_vigente', 'lat', 'lng'],
#       dtype='object')

# %%
df=rain[['raintomorrow','lat', 'lng','location']]

# %%
df['raintomorrow']=df['raintomorrow'].apply(lambda x: 1 if x=='Yes' else 0)
# Out:
# C:\Users\pedro\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Primeira tentativa com lat,lng e média de raintomorrow

# %%
df.columns
# Out:
# Index(['raintomorrow', 'lat', 'lng', 'location', 'labels'], dtype='object')

# %%
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(df.lng.unique(), df.lat.unique())

# %%
from sklearn.preprocessing import StandardScaler
X =df.groupby('location')['lat','lng','raintomorrow'].mean()
X_std = StandardScaler().fit_transform(X)
# Out:
# C:\Users\pedro\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans
model = KMeans()
visualizer = KElbowVisualizer(model, k=(1,12))

visualizer.fit(X_std)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure

# %%
kmeans = KMeans(4)
kmeans.fit(X_std)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
X['labels']=kmeans.labels_

# %%
X
# Out:
#                         lat         lng  raintomorrow  labels
# location
# Adelaide         -34.928181  138.599931      0.222654       0
# Albany           -35.024782  117.883608      0.299072       3
# Albury           -36.080477  146.916280      0.205247       0
# AliceSprings     -23.696819  133.878704      0.080501       2
# BadgerysCreek    -33.877277  150.686196      0.199112       0
# Ballarat         -37.562263  143.860722      0.257926       0
# Bendigo          -36.758877  144.282593      0.185234       0
# Brisbane         -27.468968  153.023499      0.224296       0
# Cairns           -16.920666  145.772185      0.317938       1
# Canberra         -35.297591  149.101268      0.184026       0
# Cobar            -31.498333  145.834444      0.129183       2
# CoffsHarbour     -30.313697  153.068648      0.294277       0
# Dartmoor         -37.922544  141.276655      0.313286       0
# Darwin           -12.460440  130.841047      0.266917       1
# GoldCoast        -35.418780  138.325400      0.260067       0
# Hobart           -42.882509  147.328123      0.238708       0
# Katherine        -14.464231  132.263857      0.169981       1
# Launceston       -41.434081  147.137350      0.230845       0
# Melbourne        -37.814218  144.963161      0.261191       0
# MelbourneAirport -37.664873  144.821983      0.217016       0
# Mildura          -34.184726  142.162497      0.108746       2
# Moree            -29.461720  149.840715      0.138052       2
# MountGambier     -37.808830  140.767346      0.303630       0
# MountGinini      -25.000000  135.000000      0.281734       1
# Newcastle        -32.927288  151.781253      0.247377       0
# Nhil             -35.432528  141.283319      0.154238       2
# NorahHead        -33.283303  151.566235      0.275862       0
# NorfolkIsland    -25.000000  135.000000      0.310054       1
# Nuriootpa        -34.469335  138.993901      0.197202       0
# PearceRAAF       -25.000000  135.000000      0.182839       2
# Penrith          -33.751079  150.694168      0.200742       0
# Perth            -31.952712  115.860480      0.202004       3
# PerthAirport     -31.992972  116.029108      0.188435       3
# Portland         -38.363435  141.605605      0.365487       0
# Richmond         -37.820396  145.002515      0.189766       0
# Sale             -38.106605  147.067945      0.214333       0
# SalmonGums       -32.988361  121.855671      0.159729       3
# Sydney           -33.854816  151.216454      0.259215       0
# SydneyAirport    -33.889794  150.710759      0.257571       0
# Townsville       -19.256939  146.823954      0.171118       1
# Tuggeranong      -35.420977  149.092134      0.189460       0
# Uluru            -25.345555  131.036962      0.076266       2
# WaggaWagga       -35.094525  147.360657      0.180108       0
# Walpole          -34.977680  116.731006      0.336644       3
# Watsonia         -37.711002  145.083635      0.246082       0
# Williamtown      -32.815000  151.842778      0.274187       0
# Witchcliffe      -34.026335  115.100477      0.297764       3
# Wollongong       -34.424394  150.893850      0.239021       0
# Woomera          -31.199914  136.825353      0.067559       2

# %%
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(X.lng, X.lat,c=X.labels, cmap='rainbow')

# %% [markdown]
# # Segunda tentativa com PCA nas coordenadas geograficas e media de rain

# %%
from sklearn.decomposition import PCA

# %%
X=df.groupby('location')['location','lat','lng','raintomorrow'].mean().reset_index()
coord = X[['lat','lng']]
pca = PCA(1)
pca.fit(coord)
X_coord=pca.transform(coord)
X['coord']= X_coord
X_std = StandardScaler().fit_transform(X[['coord','raintomorrow']])
# Out:
# C:\Users\pedro\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans
model = KMeans()
visualizer = KElbowVisualizer(model, k=(1,12))

visualizer.fit(X_std)        # Fit the data to the visualizer
visualizer.show()

# %%
kmeans = KMeans(4)
kmeans.fit(X_std)
kmeans.labels_
# Out:
# array([2, 3, 2, 0, 2, 1, 2, 2, 1, 2, 2, 1, 1, 3, 1, 2, 0, 2, 1, 2, 0, 2,
#        1, 1, 1, 2, 1, 1, 2, 0, 2, 3, 3, 1, 2, 2, 0, 1, 1, 2, 2, 0, 2, 3,
#        1, 1, 3, 2, 0])

# %%
X['labels']=kmeans.labels_

# %%
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(X.lng, X.lat,c=X.labels, cmap='rainbow')
